# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import keras.datasets
import matplotlib.pyplot as plt

# %%
#we are using the fashion mnist dataset for training
#we are only going to need data for the training no need for the labels
(x_train,y_train),(x_test,y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
#we are converting the values of the photos to range [-1,1] foe better evalutation
def preprocess(dataset):
  dataset = (dataset - 127.5) / 127.5

  return dataset

# %%
x_train  = preprocess(x_train)

# %%
fig = plt.figure(figsize=(18, 5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)


for n , i in enumerate(list(np.random.randint(0 ,x_train.shape[0],30))):
    plt.subplot(3,10,n+1)
    plt.imshow(x_train[i], cmap = "gray")
    plt.axis('off')

# %%
# the discriminator Architecture is the same as a normal convolution network used for binary classification between two classes

dis_input = keras.layers.Input(shape = (28,28,1))
x = keras.layers.Conv2D(28,kernel_size = 4,strides = 2, padding = 'same',use_bias = False)(dis_input)
x = keras.layers.LeakyReLU(0.2)(x)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.Conv2D(56,kernel_size = 4,strides = 2, padding = 'same',use_bias = False)(x)
x = keras.layers.BatchNormalization(momentum= 0.9)(x)
x = keras.layers.LeakyReLU(0.2)(x)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.Conv2D(112,kernel_size = 4,strides = 2, padding = 'same',use_bias = False)(x)
x = keras.layers.BatchNormalization(momentum= 0.9)(x)
x = keras.layers.LeakyReLU(0.2)(x)
x = keras.layers.Dropout(0.3)(x)
x = keras.layers.Conv2D(1,kernel_size = 4,strides = 1 ,padding = 'valid', activation = "sigmoid" ,use_bias = False)(x)
dis_output = keras.layers.Flatten()(x)

discriminator = keras.models.Model(dis_input,dis_output)

# %%
discriminator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 14, 14, 28)        448
#
#  leaky_re_lu (LeakyReLU)     (None, 14, 14, 28)        0
#
#  dropout (Dropout)           (None, 14, 14, 28)        0
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 56)          25088
#
#  batch_normalization (Batch  (None, 7, 7, 56)          224
#  Normalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 7, 7, 56)          0
#
#  dropout_1 (Dropout)         (None, 7, 7, 56)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 112)         100352
#
#  batch_normalization_1 (Bat  (None, 4, 4, 112)         448
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 4, 4, 112)         0
#
#  dropout_2 (Dropout)         (None, 4, 4, 112)         0
#
#  conv2d_3 (Conv2D)           (None, 1, 1, 1)           1792
#
#  flatten (Flatten)           (None, 1)                 0
#
# =================================================================
# Total params: 128352 (501.38 KB)
# Trainable params: 128016 (500.06 KB)
# Non-trainable params: 336 (1.31 KB)
# _________________________________________________________________

# %%
#the generator takes in a multivariate noraml random vector
# and generate an image with the same dimension as the images in the original dataset
dimentions = 100
gen_input = keras.layers.Input(shape = (dimentions,))
x = keras.layers.Reshape((1,1,dimentions))(gen_input)
x = keras.layers.Conv2DTranspose(112,kernel_size = 4,strides = 1 ,padding = 'valid',use_bias = False)(x)
x = keras.layers.BatchNormalization(momentum= 0.9)(x)
x = keras.layers.LeakyReLU(0.2)(x)
x = keras.layers.Conv2DTranspose(56,kernel_size = 4,strides = 2 ,padding = 'same',use_bias = False)(x)
x = keras.layers.BatchNormalization(momentum= 0.9)(x)
x = keras.layers.LeakyReLU(0.2)(x)
x = keras.layers.Conv2DTranspose(28,kernel_size = 4,strides = 2 ,padding = 'same',use_bias = False)(x)
x = keras.layers.BatchNormalization(momentum= 0.9)(x)
x = keras.layers.LeakyReLU(0.2)(x)
gen_output = keras.layers.Conv2DTranspose(1, kernel_size =13, strides = 1, padding = "valid", use_bias = False ,activation = 'tanh')(x)

generator_model = keras.models.Model(gen_input,gen_output)

# %%
generator_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100)]             0
#
#  reshape (Reshape)           (None, 1, 1, 100)         0
#
#  conv2d_transpose (Conv2DTr  (None, 4, 4, 112)         179200
#  anspose)
#
#  batch_normalization_2 (Bat  (None, 4, 4, 112)         448
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 4, 4, 112)         0
#
#  conv2d_transpose_1 (Conv2D  (None, 8, 8, 56)          100352
#  Transpose)
#
#  batch_normalization_3 (Bat  (None, 8, 8, 56)          224
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 8, 8, 56)          0
#
#  conv2d_transpose_2 (Conv2D  (None, 16, 16, 28)        25088
#  Transpose)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 28)        112
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 28)        0
#
#  conv2d_transpose_3 (Conv2D  (None, 28, 28, 1)         4732
#  Transpose)
#
# =================================================================
# Total params: 310156 (1.18 MB)
# Trainable params: 309764 (1.18 MB)
# Non-trainable params: 392 (1.53 KB)
# _________________________________________________________________

# %%
class GAN(keras.models.Model):
  def __init__(self,gen,dis,latent_dim):
    super(GAN,self).__init__()
    self.genetrator = gen
    self.discriminator = dis
    self.latent_dim = latent_dim

  def compile(self,d_optimizer,g_optimizer):

    super(GAN,self).compile()

    self.loss_fun = keras.losses.BinaryCrossentropy()
    self.g_optimizer = g_optimizer
    self.d_optimizer = d_optimizer

    self.g_loss_metric = keras.metrics.Mean(
        name = "generator_loss")
    self.d_loss_metric = keras.metrics.Mean(
        name = "discriminator_loss")

    self.d_real_accuracy = keras.metrics.BinaryAccuracy(
        name = "discriminator_real_accuracy")
    self.d_fake_accuracy = keras.metrics.BinaryAccuracy(
        name = "discriminator_fake_accuracy")

    self.d_accuracy = keras.metrics.BinaryAccuracy(
        name = "discrimivator_accuracy")
    self.g_accuracy = keras.metrics.BinaryAccuracy(
        name = "genetrator_accuracy")

  @property
  def metrics(self):
    return [
    self.g_loss_metric,
    self.d_loss_metric ,
    self.d_real_accuracy ,
    self.d_fake_accuracy,
    self.d_accuracy ,
    self.g_accuracy
    ]

  def train_step(self,real_images):
    batch_size = real_images.shape[0]
    random_vector = tf.random.normal(
        shape = (batch_size,self.latent_dim))

    with tf.GradientTape() as gen_tape ,tf.GradientTape() as dis_tape:
      generated_images = self.genetrator(
          random_vector , training = True)

      real_predicitons = self.discriminator(
          real_images , training = True)
      fake_predictions = self.discriminator(
          generated_images , training = True)

      real_labels = tf.ones_like(real_predicitons)
      fake_labels = tf.zeros_like(fake_predictions)

      real_noise_labels = real_labels + 0.1 * tf.random.uniform(
          tf.shape(real_predicitons))
      fake_noise_labels = fake_labels + 0.1 * tf.random.uniform(
          tf.shape(fake_predictions))

      dis_loss_real = self.loss_fun(
          real_noise_labels,real_predicitons)
      dis_loss_fake = self.loss_fun(
          fake_noise_labels,fake_predictions)

      dis_loss = (dis_loss_real + dis_loss_fake) / 2.0

      gen_loss = self.loss_fun(real_labels,fake_predictions)

      gradient_discriminator = dis_tape.gradient(
          dis_loss,self.discriminator.trainable_variables)

      self.d_optimizer.apply_gradients(
          zip(gradient_discriminator, self.discriminator.trainable_variables))

      gradient_generator = gen_tape.gradient(
          gen_loss,self.genetrator.trainable_variables)

      self.g_optimizer.apply_gradients(
          zip(gradient_generator, self.genetrator.trainable_variables))

      self.d_loss_metric.update_state(dis_loss)
      self.g_loss_metric.update_state(gen_loss)
      self.d_fake_accuracy.update_state(fake_labels,fake_predictions)
      self.d_real_accuracy.update_state(real_labels,real_predicitons)
      self.d_accuracy.update_state(
          [real_labels,fake_labels],
           [real_predicitons,fake_predictions])
      self.g_accuracy(real_labels,fake_predictions)

      return {m.name: m.result() for m in self.metrics}

# %%
gan = GAN(dis = discriminator,gen = generator_model, latent_dim = dimentions)

# %%
gan.compile(
    g_optimizer= keras.optimizers.Adam(
      learning_rate=0.002 ,beta_1= 0.5,beta_2= 0.999),
    d_optimizer= keras.optimizers.Adam(
        learning_rate=0.0002,beta_1= 0.5,beta_2= 0.999))

# %%
check_point = keras.callbacks.ModelCheckpoint(
    save_weight_only = True,
    filepath='/content/drive/MyDrive/gan_checkpoint',save_freq="epoch")

# %%
gan.fit(x_train,epochs= 100,batch_size= 32)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 42s 9ms/step - generator_loss: 1.9315 - discriminator_loss: 0.3137 - discriminator_real_accuracy: 0.8687 - discriminator_fake_accuracy: 0.7928 - discrimivator_accuracy: 0.8308 - genetrator_accuracy: 0.2072
# Epoch 2/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 1.6682 - discriminator_loss: 0.3173 - discriminator_real_accuracy: 0.8802 - discriminator_fake_accuracy: 0.8141 - discrimivator_accuracy: 0.8471 - genetrator_accuracy: 0.1859
# Epoch 3/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 1.7884 - discriminator_loss: 0.3331 - discriminator_real_accuracy: 0.8803 - discriminator_fake_accuracy: 0.7938 - discrimivator_accuracy: 0.8371 - genetrator_accuracy: 0.2062
# Epoch 4/100
# 1875/1875 [==============================] - 18s 9ms/step - generator_loss: 2.2186 - discriminator_loss: 0.2357 - discriminator_real_accuracy: 0.9215 - discriminator_fake_accuracy: 0.8452 - discrimivator_accuracy: 0.8834 - genetrator_accuracy: 0.1548
# Epoch 5/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.6394 - discriminator_loss: 0.1807 - discriminator_real_accuracy: 0.9386 - discriminator_fake_accuracy: 0.8669 - discrimivator_accuracy: 0.9028 - genetrator_accuracy: 0.1331
# Epoch 6/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.5851 - discriminator_loss: 0.2080 - discriminator_real_accuracy: 0.9329 - discriminator_fake_accuracy: 0.8535 - discrimivator_accuracy: 0.8932 - genetrator_accuracy: 0.1465
# Epoch 7/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.4723 - discriminator_loss: 0.2450 - discriminator_real_accuracy: 0.9213 - discriminator_fake_accuracy: 0.8363 - discrimivator_accuracy: 0.8788 - genetrator_accuracy: 0.1637
# Epoch 8/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.4305 - discriminator_loss: 0.2531 - discriminator_real_accuracy: 0.9184 - discriminator_fake_accuracy: 0.8322 - discrimivator_accuracy: 0.8753 - genetrator_accuracy: 0.1678
# Epoch 9/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.4891 - discriminator_loss: 0.2466 - discriminator_real_accuracy: 0.9216 - discriminator_fake_accuracy: 0.8358 - discrimivator_accuracy: 0.8787 - genetrator_accuracy: 0.1642
# Epoch 10/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.4947 - discriminator_loss: 0.2572 - discriminator_real_accuracy: 0.9183 - discriminator_fake_accuracy: 0.8280 - discrimivator_accuracy: 0.8732 - genetrator_accuracy: 0.1720
# Epoch 11/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.3386 - discriminator_loss: 0.2883 - discriminator_real_accuracy: 0.9095 - discriminator_fake_accuracy: 0.8136 - discrimivator_accuracy: 0.8615 - genetrator_accuracy: 0.1864
# Epoch 12/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.2907 - discriminator_loss: 0.2972 - discriminator_real_accuracy: 0.9048 - discriminator_fake_accuracy: 0.8094 - discrimivator_accuracy: 0.8571 - genetrator_accuracy: 0.1906
# Epoch 13/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2
100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7510 - discriminator_loss: 0.2211 - discriminator_real_accuracy: 0.9385 - discriminator_fake_accuracy: 0.8478 - discrimivator_accuracy: 0.8931 - genetrator_accuracy: 0.1522
# Epoch 58/100
# 1875/1875 [==============================] - 15s 8ms/step - generator_loss: 2.7079 - discriminator_loss: 0.2307 - discriminator_real_accuracy: 0.9313 - discriminator_fake_accuracy: 0.8404 - discrimivator_accuracy: 0.8859 - genetrator_accuracy: 0.1595
# Epoch 59/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7345 - discriminator_loss: 0.2227 - discriminator_real_accuracy: 0.9371 - discriminator_fake_accuracy: 0.8472 - discrimivator_accuracy: 0.8921 - genetrator_accuracy: 0.1528
# Epoch 60/100
# 1875/1875 [==============================] - 15s 8ms/step - generator_loss: 2.7421 - discriminator_loss: 0.2262 - discriminator_real_accuracy: 0.9354 - discriminator_fake_accuracy: 0.8452 - discrimivator_accuracy: 0.8903 - genetrator_accuracy: 0.1548
# Epoch 61/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.7546 - discriminator_loss: 0.2244 - discriminator_real_accuracy: 0.9353 - discriminator_fake_accuracy: 0.8460 - discrimivator_accuracy: 0.8906 - genetrator_accuracy: 0.1540
# Epoch 62/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7783 - discriminator_loss: 0.2192 - discriminator_real_accuracy: 0.9376 - discriminator_fake_accuracy: 0.8470 - discrimivator_accuracy: 0.8923 - genetrator_accuracy: 0.1530
# Epoch 63/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7943 - discriminator_loss: 0.2234 - discriminator_real_accuracy: 0.9363 - discriminator_fake_accuracy: 0.8466 - discrimivator_accuracy: 0.8914 - genetrator_accuracy: 0.1534
# Epoch 64/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7255 - discriminator_loss: 0.2305 - discriminator_real_accuracy: 0.9325 - discriminator_fake_accuracy: 0.8432 - discrimivator_accuracy: 0.8878 - genetrator_accuracy: 0.1568
# Epoch 65/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.7615 - discriminator_loss: 0.2284 - discriminator_real_accuracy: 0.9349 - discriminator_fake_accuracy: 0.8427 - discrimivator_accuracy: 0.8888 - genetrator_accuracy: 0.1573
# Epoch 66/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7966 - discriminator_loss: 0.2177 - discriminator_real_accuracy: 0.9399 - discriminator_fake_accuracy: 0.8502 - discrimivator_accuracy: 0.8950 - genetrator_accuracy: 0.1498
# Epoch 67/100
# 1875/1875 [==============================] - 18s 9ms/step - generator_loss: 2.7620 - discriminator_loss: 0.2199 - discriminator_real_accuracy: 0.9369 - discriminator_fake_accuracy: 0.8446 - discrimivator_accuracy: 0.8907 - genetrator_accuracy: 0.1554
# Epoch 68/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7924 - discriminator_loss: 0.2125 - discriminator_real_accuracy: 0.9414 - discriminator_fake_accuracy: 0.8514 - discrimivator_accuracy: 0.8964 - genetrator_accuracy: 0.1486
# Epoch 69/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8095 - discriminator_loss: 0.2113 - discriminator_real_accuracy: 0.9403 - discriminator_fake_accuracy: 0.8520 - discrimivator_accuracy: 0.8962 - genetrator_accuracy: 0.1480
# Epoch 70/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7480 - discriminator_loss: 0.2172 - discriminator_real_accuracy: 0.9377 - discriminator_fake_accuracy: 0.8484 - discrimivator_accuracy: 0.8930 - genetrator_accuracy: 0.1516
# Epoch 71/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8359 - discriminator_loss: 0.2103 - discriminator_real_accuracy: 0.9409 - discriminator_fake_accuracy: 0.8506 - discrimivator_accuracy: 0.8957 - genetrator_accuracy: 0.1494
# Epoch 72/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8626 - discriminator_loss: 0.2150 - discriminator_real_accuracy: 0.9408 - discriminator_fake_accuracy: 0.8496 - discrimivator_accuracy: 0.8952 - genetrator_accuracy: 0.1504
# Epoch 73/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8214 - discriminator_loss: 0.2114 - discriminator_real_accuracy: 0.9394 - discriminator_fake_accuracy: 0.8518 - discrimivator_accuracy: 0.8956 - genetrator_accuracy: 0.1482
# Epoch 74/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8024 - discriminator_loss: 0.2136 - discriminator_real_accuracy: 0.9396 - discriminator_fake_accuracy: 0.8511 - discrimivator_accuracy: 0.8953 - genetrator_accuracy: 0.1489
# Epoch 75/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.7896 - discriminator_loss: 0.2173 - discriminator_real_accuracy: 0.9385 - discriminator_fake_accuracy: 0.8480 - discrimivator_accuracy: 0.8932 - genetrator_accuracy: 0.1520
# Epoch 76/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8724 - discriminator_loss: 0.2117 - discriminator_real_accuracy: 0.9417 - discriminator_fake_accuracy: 0.8493 - discrimivator_accuracy: 0.8955 - genetrator_accuracy: 0.1507
# Epoch 77/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8324 - discriminator_loss: 0.2118 - discriminator_real_accuracy: 0.9418 - discriminator_fake_accuracy: 0.8532 - discrimivator_accuracy: 0.8975 - genetrator_accuracy: 0.1468
# Epoch 78/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8638 - discriminator_loss: 0.2011 - discriminator_real_accuracy: 0.9444 - discriminator_fake_accuracy: 0.8565 - discrimivator_accuracy: 0.9004 - genetrator_accuracy: 0.1435
# Epoch 79/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8038 - discriminator_loss: 0.2125 - discriminator_real_accuracy: 0.9393 - discriminator_fake_accuracy: 0.8502 - discrimivator_accuracy: 0.8947 - genetrator_accuracy: 0.1498
# Epoch 80/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8136 - discriminator_loss: 0.2127 - discriminator_real_accuracy: 0.9390 - discriminator_fake_accuracy: 0.8505 - discrimivator_accuracy: 0.8947 - genetrator_accuracy: 0.1495
# Epoch 81/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.7515 - discriminator_loss: 0.2243 - discriminator_real_accuracy: 0.9365 - discriminator_fake_accuracy: 0.8458 - discrimivator_accuracy: 0.8912 - genetrator_accuracy: 0.1542
# Epoch 82/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8320 - discriminator_loss: 0.2134 - discriminator_real_accuracy: 0.9382 - discriminator_fake_accuracy: 0.8487 - discrimivator_accuracy: 0.8934 - genetrator_accuracy: 0.1513
# Epoch 83/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8225 - discriminator_loss: 0.2129 - discriminator_real_accuracy: 0.9410 - discriminator_fake_accuracy: 0.8508 - discrimivator_accuracy: 0.8959 - genetrator_accuracy: 0.1491
# Epoch 84/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8274 - discriminator_loss: 0.2122 - discriminator_real_accuracy: 0.9411 - discriminator_fake_accuracy: 0.8511 - discrimivator_accuracy: 0.8961 - genetrator_accuracy: 0.1489
# Epoch 85/100
# 1875/1875 [==============================] - 18s 10ms/step - generator_loss: 2.8928 - discriminator_loss: 0.2004 - discriminator_real_accuracy: 0.9461 - discriminator_fake_accuracy: 0.8582 - discrimivator_accuracy: 0.9021 - genetrator_accuracy: 0.1418
# Epoch 86/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8493 - discriminator_loss: 0.2090 - discriminator_real_accuracy: 0.9432 - discriminator_fake_accuracy: 0.8529 - discrimivator_accuracy: 0.8980 - genetrator_accuracy: 0.1471
# Epoch 87/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8837 - discriminator_loss: 0.2068 - discriminator_real_accuracy: 0.9431 - discriminator_fake_accuracy: 0.8530 - discrimivator_accuracy: 0.8981 - genetrator_accuracy: 0.1470
# Epoch 88/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8298 - discriminator_loss: 0.2064 - discriminator_real_accuracy: 0.9421 - discriminator_fake_accuracy: 0.8542 - discrimivator_accuracy: 0.8981 - genetrator_accuracy: 0.1458
# Epoch 89/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8929 - discriminator_loss: 0.1988 - discriminator_real_accuracy: 0.9446 - discriminator_fake_accuracy: 0.8572 - discrimivator_accuracy: 0.9009 - genetrator_accuracy: 0.1428
# Epoch 90/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.9282 - discriminator_loss: 0.2026 - discriminator_real_accuracy: 0.9439 - discriminator_fake_accuracy: 0.8560 - discrimivator_accuracy: 0.8999 - genetrator_accuracy: 0.1440
# Epoch 91/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.8801 - discriminator_loss: 0.2038 - discriminator_real_accuracy: 0.9438 - discriminator_fake_accuracy: 0.8543 - discrimivator_accuracy: 0.8991 - genetrator_accuracy: 0.1457
# Epoch 92/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.8735 - discriminator_loss: 0.2079 - discriminator_real_accuracy: 0.9416 - discriminator_fake_accuracy: 0.8533 - discrimivator_accuracy: 0.8975 - genetrator_accuracy: 0.1467
# Epoch 93/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.9653 - discriminator_loss: 0.1955 - discriminator_real_accuracy: 0.9464 - discriminator_fake_accuracy: 0.8576 - discrimivator_accuracy: 0.9020 - genetrator_accuracy: 0.1424
# Epoch 94/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.9268 - discriminator_loss: 0.1961 - discriminator_real_accuracy: 0.9458 - discriminator_fake_accuracy: 0.8598 - discrimivator_accuracy: 0.9028 - genetrator_accuracy: 0.1402
# Epoch 95/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.9835 - discriminator_loss: 0.1866 - discriminator_real_accuracy: 0.9496 - discriminator_fake_accuracy: 0.8637 - discrimivator_accuracy: 0.9067 - genetrator_accuracy: 0.1363
# Epoch 96/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.9593 - discriminator_loss: 0.1973 - discriminator_real_accuracy: 0.9462 - discriminator_fake_accuracy: 0.8572 - discrimivator_accuracy: 0.9017 - genetrator_accuracy: 0.1428
# Epoch 97/100
# 1875/1875 [==============================] - 16s 8ms/step - generator_loss: 2.9892 - discriminator_loss: 0.1944 - discriminator_real_accuracy: 0.9475 - discriminator_fake_accuracy: 0.8581 - discrimivator_accuracy: 0.9028 - genetrator_accuracy: 0.1419
# Epoch 98/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.9826 - discriminator_loss: 0.2020 - discriminator_real_accuracy: 0.9460 - discriminator_fake_accuracy: 0.8548 - discrimivator_accuracy: 0.9004 - genetrator_accuracy: 0.1452
# Epoch 99/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.9351 - discriminator_loss: 0.1934 - discriminator_real_accuracy: 0.9461 - discriminator_fake_accuracy: 0.8597 - discrimivator_accuracy: 0.9029 - genetrator_accuracy: 0.1403
# Epoch 100/100
# 1875/1875 [==============================] - 16s 9ms/step - generator_loss: 2.9529 - discriminator_loss: 0.2030 - discriminator_real_accuracy: 0.9434 - discriminator_fake_accuracy: 0.8540 - discrimivator_accuracy: 0.8987 - genetrator_accuracy: 0.1460

# %%
z_samples = tf.random.normal(shape = (30,dimentions))

# %%
generations = generator_model.predict(z_samples)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
fig = plt.figure(figsize=(18, 5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Output the grid of faces
for i in range(30):
    ax = fig.add_subplot(3, 10, i + 1)
    ax.axis("off")
    ax.imshow(generations[i, :, :], cmap="Greys")
